# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="TLI09FOgOJQYNwBUaa8X")
project = rf.workspace("roboflow-100").project("animals-ij5d2")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 9.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to animals-2 in yolov11:: 100%|██████████| 2012/2012 [00:00<00:00, 7591.04it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 921.5/921.5 kB 39.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 95.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# %cd /content/animals-2

# !rm data.yaml
# !echo 'name:' >> data.yaml

# !echo '- cat' >> data.yaml
# !echo '- chicken' >> data.yaml
# !echo '- cow' >> data.yaml
# !echo '- dog' >> data.yaml
# !echo '- fox' >> data.yaml
# !echo '- goat' >> data.yaml
# !echo '- horse' >> data.yaml
# !echo '- person' >> data.yaml
# !echo '- racoon' >> data.yaml

# !echo 'nc: 9' >> data.yaml

# !echo 'train: /content/animals-2/train/images' >> data.yaml
# !echo 'val: /content/animals-2/valid/images' >> data.yaml
# !echo 'test: /content/animals-2/test/images' >> data.yaml
# Out:
# [Errno 2] No such file or directory: '/content/animals-2'
# /content/yolov12/animals-2
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-31-750408870949> in <cell line: 0>()
#       1 get_ipython().run_line_magic('cd', '/content/animals-2')
#       2
# ----> 3 get_ipython().system('rm data.yaml')
#       4 get_ipython().system("echo 'name:' >> data.yaml")
#       5
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     121       kwargs.update({'also_return_output': True})
#     122
# --> 123     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     124
#     125     if pip_warn:
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
# ...

# %%
# # Python function to automatically create data.yaml config file
# # 1. Reads "classes.txt" file to get list of class names
# # 2. Creates data dictionary with correct paths to folders, number of classes, and names of classes
# # 3. Writes data in YAML format to data.yaml

# import yaml
# import os

# def create_data_yaml(path_to_classes_txt, path_to_data_yaml):

#   # Read class.txt to get class names
#   if not os.path.exists(path_to_classes_txt):
#     print(f'classes.txt file not found! Please create a classes.txt labelmap and move it to {path_to_classes_txt}')
#     return
#   with open(path_to_classes_txt, 'r') as f:
#     classes = []
#     for line in f.readlines():
#       if len(line.strip()) == 0: continue
#       classes.append(line.strip())
#   number_of_classes = len(classes)

#   # Create data dictionary
#   data = {
#       'path': '/content/animals-2',
#       'train': 'train/images',
#       'val': 'valid/images',
#       'test': 'test/images',
#       'nc': number_of_classes,
#       'names': classes
#   }

#   # Write data to YAML file
#   with open(path_to_data_yaml, 'w') as f:
#     yaml.dump(data, f, sort_keys=False)
#   print(f'Created config file at {path_to_data_yaml}')

#   return

# # Define path to classes.txt and run functiont
# path_to_classes_txt = '/content/animals-2/classes.txt'
# path_to_data_yaml = '/content/data.yaml'

# create_data_yaml(path_to_classes_txt, path_to_data_yaml)

# print('\nFile contents:\n')
# !cat /content/data.yaml

# %%
# !yolo detect train data='/content/animals-2/data.yaml' model=yolo12s.pt epochs=60 imgsz=640 plots=True
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !which yolo
# Out:
# /usr/local/bin/yolo

# %%
# !yolo detect predict model=runs/detect/train2/weights/best.pt source=animals-2/valid/images save=True
# Out:
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 238 layers, 9,416,283 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/200 /content/animals-2/valid/images/104_jpg.rf.33db265d10eb0e656ec6b8a84835bac6.jpg: 480x640 1 class_0, 46.6ms
# image 2/200 /content/animals-2/valid/images/110_jpg.rf.ca06f6947e403d286173bf95bff61c8b.jpg: 576x640 1 class_5, 47.7ms
# image 3/200 /content/animals-2/valid/images/111_jpg.rf.9b3dfc7d56701c1f11a0fb8e9abe038c.jpg: 480x640 1 class_0, 13.1ms
# image 4/200 /content/animals-2/valid/images/113_jpg.rf.37efd074bf706ec7aaa336aa8178d501.jpg: 640x576 1 class_5, 42.6ms
# image 5/200 /content/animals-2/valid/images/118_jpg.rf.9527e2f245735b8360876e82d5ea6a43.jpg: 384x640 1 class_1, 43.7ms
# image 6/200 /content/animals-2/valid/images/120_jpg.rf.d773a8beecfa3f07f7b412c14b104b2c.jpg: 448x640 1 class_6, 45.1ms
# ...

# %%
import glob
from IPython.display import Image, display
import random
for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:20]:
  display(Image(filename=image_path, height=400))
  print('\n')

# %%
# Tạo folder nếu chưa tồn tại
# !mkdir -p /content/my_model

# Sao chép mô hình và kết quả huấn luyện
# !cp /content/runs/detect/train/weights/best.pt /content/my_model/my_model.pt
# !cp -r /content/runs/detect/train /content/my_model/train

# Nén toàn bộ thư mục vào 1 file zip
# %cd /content/my_model
# !zip -r /content/my_model.zip ./*  # Nén tất cả mọi thứ trong my_model
# %cd /content
# Out:
# /content/my_model
#   adding: my_model.pt (deflated 8%)
#   adding: train/ (stored 0%)
#   adding: train/labels_correlogram.jpg (deflated 40%)
#   adding: train/val_batch0_pred.jpg (deflated 8%)
#   adding: train/R_curve.png (deflated 8%)
#   adding: train/val_batch2_labels.jpg (deflated 8%)
#   adding: train/results.csv (deflated 62%)
#   adding: train/val_batch0_labels.jpg (deflated 8%)
#   adding: train/val_batch1_pred.jpg (deflated 7%)
#   adding: train/train_batch0.jpg (deflated 6%)
#   adding: train/PR_curve.png (deflated 13%)
#   adding: train/val_batch2_pred.jpg (deflated 7%)
#   adding: train/F1_curve.png (deflated 7%)
#   adding: train/events.out.tfevents.1739803557.86f1d75a4f41.2034.0 (deflated 88%)
#   adding: train/P_curve.png (deflated 10%)
#   adding: train/labels.jpg (deflated 26%)
#   adding: train/train_batch2.jpg (deflated 4%)
#   adding: train/train_batch4400.jpg (deflated 12%)
#   adding: train/confusion_matrix_normalized.png (deflated 20%)
# ...

# %%
from google.colab import files

files.download('/content/my_model.zip')

# %%
Image(filename='/content/runs/detect/train4/confusion_matrix.png', width=800)

# %% [markdown]
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="TLI09FOgOJQYNwBUaa8X")
project = rf.workspace("roboflow-100").project("animals-ij5d2")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to animals-2 in yolov11:: 100%|██████████| 2012/2012 [00:00<00:00, 11085.02it/s]

# %%
# !unzip /content/my_model.zip -d /content/my_model
# Out:
# Archive:  /content/my_model.zip
#   inflating: /content/my_model/my_model.pt
#    creating: /content/my_model/train/
#   inflating: /content/my_model/train/labels_correlogram.jpg
#   inflating: /content/my_model/train/val_batch0_pred.jpg
#   inflating: /content/my_model/train/R_curve.png
#   inflating: /content/my_model/train/val_batch2_labels.jpg
#   inflating: /content/my_model/train/results.csv
#   inflating: /content/my_model/train/val_batch0_labels.jpg
#   inflating: /content/my_model/train/val_batch1_pred.jpg
#   inflating: /content/my_model/train/train_batch0.jpg
#   inflating: /content/my_model/train/PR_curve.png
#   inflating: /content/my_model/train/val_batch2_pred.jpg
#   inflating: /content/my_model/train/F1_curve.png
#   inflating: /content/my_model/train/events.out.tfevents.1739803557.86f1d75a4f41.2034.0
#   inflating: /content/my_model/train/P_curve.png
#   inflating: /content/my_model/train/labels.jpg
#   inflating: /content/my_model/train/train_batch2.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 24.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 95.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 81.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# %cd /content/animals-2

# !rm data.yaml
# !echo 'name:' >> data.yaml

# !echo '- cat' >> data.yaml
# !echo '- chicken' >> data.yaml
# !echo '- cow' >> data.yaml
# !echo '- dog' >> data.yaml
# !echo '- fox' >> data.yaml
# !echo '- goat' >> data.yaml
# !echo '- horse' >> data.yaml
# !echo '- person' >> data.yaml
# !echo '- racoon' >> data.yaml

# !echo 'nc: 9' >> data.yaml

# !echo 'train: /content/animals-2/train/images' >> data.yaml
# !echo 'val: /content/animals-2/valid/images' >> data.yaml
# !echo 'test: /content/animals-2/test/images' >> data.yaml
# Out:
# /content/animals-2

# %%
# !yolo detect predict model=/content/my_model/my_model.pt source=/content/animals-2/test/images save=True

# %%
import glob
from IPython.display import Image, display
import random
for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:20]:
  display(Image(filename=image_path, height=400))
  print('\n')

# %% [markdown]
# # Backyard

# %%
print('\n'.join
([''.join
([('Engineer'[(x-y)%8 ]
if((x*0.042)**2+(y*0.1)**2-1)**3-(x*0.04)**2*(y*0.1)**3<=0
   else' ')
for x in range(-30,30)])
for y in range(15,-15,-1)]))
# Out:
#
#
#
#                eerEngin               neerEngi
#           ngineerEngineerEng     EngineerEngineerEn
#        rEngineerEngineerEngineerEngineerEngineerEngine
#       rEngineerEngineerEngineerEngineerEngineerEngineer
#      rEngineerEngineerEngineerEngineerEngineerEngineerEn
#     rEngineerEngineerEngineerEngineerEngineerEngineerEngi
#     EngineerEngineerEngineerEngineerEngineerEngineerEngin
#     ngineerEngineerEngineerEngineerEngineerEngineerEngine
#     gineerEngineerEngineerEngineerEngineerEngineerEnginee
#     ineerEngineerEngineerEngineerEngineerEngineerEngineer
#      eerEngineerEngineerEngineerEngineerEngineerEngineer
#       rEngineerEngineerEngineerEngineerEngineerEngineer
#        ngineerEngineerEngineerEngineerEngineerEngineer
#         ineerEngineerEngineerEngineerEngineerEngineer
#          eerEngineerEngineerEngineerEngineerEngineer
#            EngineerEngineerEngineerEngineerEnginee
#              ineerEngineerEngineerEngineerEngine
# ...

# %%
import torch
from ultralytics import YOLO

model = YOLO("/content/my_model/my_model.pt")

results = model.predict("/content/animals-2/train/images/991_jpg.rf.32cfe2206feb0c3766ec219573613daf.jpg")

predictions = results[0].boxes.data  # Bounding boxes

# Shape
print("Shape of prediction:", predictions.shape)


print(predictions[:5])
# Out:
# image 1/1 /content/animals-2/train/images/991_jpg.rf.32cfe2206feb0c3766ec219573613daf.jpg: 384x640 2 class_6s, 2 class_7s, 13.5ms
# Speed: 1.6ms preprocess, 13.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Shape of prediction: torch.Size([4, 6])
# tensor([[ 80.6363,  36.8565, 215.6069, 142.7038,   0.9608,   6.0000],
#         [ 10.6327,  37.5525,  35.0082,  89.1453,   0.9126,   7.0000],
#         [  0.0000,  57.4129,  51.9172, 108.7775,   0.8928,   6.0000],
#         [122.1608,  18.2825, 158.3179, 105.2781,   0.8846,   7.0000]], device='cuda:0')

# %%
import cv2
import torch
from ultralytics import YOLO
from google.colab.patches import cv2_imshow


model = YOLO("/content/my_model/my_model.pt")

image_path = "/content/animals-2/train/images/991_jpg.rf.32cfe2206feb0c3766ec219573613daf.jpg"
image = cv2.imread(image_path)

results = model(image_path)  # Dự đoán bounding boxes

height, width, _ = image.shape

for result in results:
    for box in result.boxes.data:
        x_center, y_center, w, h, conf, class_id = box.tolist()

        # Chuyển tọa độ về pixel thực tế
        x_center = int(x_center)
        y_center = int(y_center)
        w = int(w)
        h = int(h)

        # Tính toán bounding box
        x_min = int(x_center - w / 2)
        y_min = int(y_center - h / 2)
        x_max = int(x_center + w / 2)
        y_max = int(y_center + h / 2)

        # Vẽ bounding box
        cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)

        # Vẽ điểm tâm x_center, y_center
        cv2.circle(image, (x_center, y_center), 5, (0, 0, 255), -1)


        label = f"Class {int(class_id)} ({conf:.2f})"
        cv2.putText(image, label, (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

cv2_imshow(image)
# Out:
# image 1/1 /content/animals-2/train/images/991_jpg.rf.32cfe2206feb0c3766ec219573613daf.jpg: 384x640 2 class_6s, 2 class_7s, 11.5ms
# Speed: 1.5ms preprocess, 11.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=266x152>

# %% [markdown]
# # YOLOv12

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="TLI09FOgOJQYNwBUaa8X")
project = rf.workspace("roboflow-100").project("animals-ij5d2")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 10.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to animals-2 in yolov11:: 100%|██████████| 2012/2012 [00:00<00:00, 5819.42it/s]

# %%
# %cd /content
# !git clone https://github.com/sunsmarterjie/yolov12.git
# %cd yolov12
# Out:
# /content
# Cloning into 'yolov12'...
# remote: Enumerating objects: 766, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 766 (delta 30), reused 21 (delta 11), pack-reused 707 (from 2)
# Receiving objects: 100% (766/766), 1.44 MiB | 20.72 MiB/s, done.
# Resolving deltas: 100% (320/320), done.
# /content/yolov12

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 921.5/921.5 kB 35.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 85.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 43.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 95.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
model = YOLO("yolo12s.pt")
model.train(data="/content/animals-2/data.yaml", epochs=10)  # Train lại để model nhận dạng lại class :((
# Out:
# ...
# 100%|██████████| 18.1M/18.1M [00:00<00:00, 341MB/s]
# New https://pypi.org/project/ultralytics/8.3.78 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.63 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/yolov12/runs/detect/train4/weights/best.pt')
model.val(data='/content/animals-2/data.yaml', save_json=True)
# Out:
# Ultralytics 8.3.63 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv12s summary (fused): 352 layers, 9,234,750 parameters, 0 gradients, 21.2 GFLOPs
# val: Scanning /content/animals-2/valid/labels.cache... 200 images, 0 backgrounds, 0 corrupt: 100%|██████████| 200/200 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:02<00:00,  4.42it/s]
#                    all        200        351      0.908      0.768      0.882      0.685
#                    cat         18         18      0.817      0.833      0.906      0.664
#                chicken         18         51      0.924      0.549      0.752       0.51
#                    cow         23         51      0.908      0.686      0.753      0.524
#                    dog         24         26      0.879      0.841      0.943      0.821
#                    fox         20         21      0.926      0.857      0.942      0.814
# ...

# %%
from ultralytics import YOLO



results = model.train(
  data='/content/animals-2/data.yaml',
  epochs=80,
  batch=16,
  imgsz=512,
  scale=0.5,  # S:0.9; M:0.9; L:0.9; X:0.9
  mosaic=0.0,
  mixup=0.0,  # S:0.05; M:0.15; L:0.15; X:0.2
  copy_paste=0.1,  # S:0.15; M:0.4; L:0.5; X:0.6
  device="cuda",
)


metrics = model.val()


results = model("/content/animals-2/test/images/912_jpg.rf.f136e8a8c272df3fc6328884c1243233.jpg")
results[0].show()
# Out:
# New https://pypi.org/project/ultralytics/8.3.78 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.63 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
